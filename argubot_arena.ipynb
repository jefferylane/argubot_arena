# %% [markdown]
# # ArguBot Arena: Prompt Engineering a Debate on Responsible AI
#
# In this assignment you will configure an LLM through the use of prompts and system prompts to defend a position on a contentious/controversial issue around responsible AI usage.
#
# This notebook is both a reference and where you will complete the assignment. As such, it is broken into several sections.
#
# The first two sections:
# 1. Provide an introduction to using Ollama to load and interact with an LLM, and
# 2. Show what a system prompt is and how it can be used to configure an LLM's behavior.
#
# After, in the next section you will:
#
# 3. Write your own system prompt to have the LLM support only one position of a debate topic.
# Note that in order to _win_ the debate your LLM must stay on topic and not stray out of their role as a debater. For example, if the LLM tries to support both sides of the argument, or deviates in anyway, then they would lose (and you would lose points).
#
# Lastly, in the final section you will:
#
# 4. Manage two LLMs(debaters), prompting both appropiately and maintaining context so that the two opponents can effectively respond to one another's arguments.
#
# __Note:__
# It is important to recognize ahead of time that you will likely need to experiment with your prompts several times. In other words, this is not a notebook you will be able to run through quickly and execute each code cell just one time. You will likely need to run and re-run some code cells several times to see how the LLM behaves for your given prompt, then modify the prompt accordingly between each run. While this may seem tedious and unneccessary, it is the reality of working with LLMs and building LLM applications.
#
# If you are working locally, already have Ollama installed, as well as the LLM(s) you want to use, then you can jump to Step 1. below (code cell with `import ollama`). If you are usign Colab or another online platform, then click below and go to Step 0. to install ollama and start the Ollama server.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MSU-CS3120/argubot_arena/blob/main/argubot_arena.ipynb)
#
# ---
#
# ### 0. Install Ollama and download chosen LLM(s)
#
# Some of this section may seem unfamiliar to you because when using Jupyter notebooks we usually don't need to execute anything outside of the notebook itself. In this case though, because Ollama runs using a client/server model, you'll need to set up and access a terminal. So first run this code cell to enable a terminal.

# %%
# !pip install ollama
import ollama
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ollama in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (4.12.0)
# Requirement already satisfied: certifi in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)

# %% [markdown]
# To start the terminal run the following code cell.

# %%
# %xterm
# Out:
# Launching Xterm...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('xterm', '')
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Library/Python/3.9/lib/python/site-packages/colabxterm/notebook.py:100, in _xterm_magic(args_string)
#      97         break
#      98     port = port+1
# --> 100 manager.start(parsed_args, port)
#     101 fn = {
#     102     _CONTEXT_COLAB: _display_colab,
#     103     _CONTEXT_IPYTHON: _display_ipython,
#     104     _CONTEXT_NONE: _display_cli,
#     105 }[_get_context()]
#     106 return fn(port=port, height=height)
#
# File ~/Library/Python/3.9/lib/python/site-packages/colabxterm/manager.py:52, in start(arguments, port, timeout)
#      51 def start(arguments, port, timeout=datetime.timedelta(seconds=60)):
# ---> 52     p = subprocess.Popen(
#      53         ["python", "-m", "colabxterm", "--port", str(port)] + arguments,
#      54     )
#      56     poll_interval_seconds = 0.5
#      57     while True:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:1821, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1819     if errno_num != 0:
#    1820         err_msg = os.strerror(errno_num)
# -> 1821     raise child_exception_type(errno_num, err_msg, err_filename)
#    1822 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'

# %% [markdown]
# Once the terminal is running, you will need to run the two commands (from within the terminal window). It is best to run these separately, starting with this line:
#
# `curl https://ollama.ai/install.sh | sh`
#
# Then this one:
#
# `ollama serve &`
#
# You will then need to select a model to download (if working on Colab, then it is recommended that you stick to smaller models, i.e. less than 2B or 3B - here is the [list of Ollama models available](https://ollama.com/search)).
#
# `ollama pull llama3.2:1b`

# %% [markdown]
# ---
#
# ### 1. Using Ollama
# To start using Ollama we'll need to import the Python ollama module. As a simple example, you'll then create a simple prompt and generate the response.
#
# Note that if you are using Ollama for the first time, or using Google Colab, then you will need to uncomment the following cell and run this first in order to download and install the Python ollama module before importing it.

# %%
# !pip install ollama
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ollama in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (4.12.0)
# Requirement already satisfied: certifi in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jefferylane/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)

# %%
import ollama

debater1 = "llama3.2:1b"
debater2 = "llama3.2:3b"

# %% [markdown]
# This next formatting function will be used later to help us view the LLM output in a clean and consistent way.

# %%
import textwrap

def format_output(text, max_width=100):
    cleaned_text = text.replace('\n', ' ') # remove newlines and extra spaces
    cleaned_text = ' '.join(cleaned_text.split())
    wrapped_text = textwrap.fill(cleaned_text, width=max_width)
    return wrapped_text

# %% [markdown]
# Next, let's define the question related to Responsible AI that we will consider.
# Without any system prompts or configuration, we'll then ask an LLM to answer our contentious/controversial question.
#
# Note: Before doing this you may need to download the LLM you are using. Below we are

# %%
# ollama.pull(debater1)
question = 'Should artificial intelligence be used to create fully autonomous military weapons?'

response = ollama.chat(model=debater1, messages=[
    {
        'role': 'user',
        'content': question,
    },
])

print(f"****** User Input ******\n{question}\n\n")
print(f"****** LLM Output ******\n{response['message']['content']}\n")
# Out:
# ****** User Input ******
# Should artificial intelligence be used to create fully autonomous military weapons?
#
#
# ****** LLM Output ******
# The use of artificial intelligence (AI) in creating fully autonomous military weapons is a complex and contentious issue. While AI has the potential to enhance military efficiency and effectiveness, its deployment in such critical systems raises significant concerns about accountability, transparency, and ethical considerations.
#
# Here are some arguments for and against using AI to create fully autonomous military weapons:
#
# Arguments For Using AI in Autonomous Weapons:
#
# 1. **Improved accuracy**: AI can analyze vast amounts of data, including sensor feeds and other information, to provide more accurate targeting decisions.
# 2. **Reduced human error**: AI systems can perform tasks without the need for human intervention, potentially reducing the risk of errors or mistakes that could result in civilian casualties or other unintended consequences.
# 3. **Increased flexibility**: AI-powered drones or robots can adapt to changing circumstances on the battlefield and adjust their tactics accordingly.
#
# Arguments Against Using AI in Autonomous Weapons:
#
# 1. **Lack of transparency**: The decision-making processes behind autonomous weapon systems are often opaque, making it difficult to understand how and why certain targets are selected.
# 2. **Accountability concerns**: Who is accountable when an autonomous system makes a mistake or causes harm? Should the manufacturer be responsible for any damages or losses resulting from such an event?
# 3. **Potential for abuse**: Autonomous weapons could be used in ways that are contrary to international humanitarian law, such as targeting civilians or using disproportionate force.
# 4. **Need for human oversight**: Even with AI-powered systems, there is a need for human oversight and control to ensure that the system is functioning as intended and not being misused.
#
# International Humanitarian Law (IHL) considerations:
#
# 1. **Proportionality**: Autonomous weapons must be used in ways that are proportional to the anticipated harm.
# 2. **Reasonableness**: The use of autonomous weapons must be reasonable, taking into account the context and circumstances on the battlefield.
# 3. **Necessity**: Autonomous weapons must be used only when necessary, and not unnecessarily.
#
# Regulatory frameworks:
#
# 1. **United Nations Convention on Certain Conventional Weapons (CCW)**: The CCW has developed guidelines for the development and use of autonomous lethal drones, including a ban on certain types of attacks.
# 2. **International Maritime Organization (IMO) Code**: The IMO Code regulates the use of unmanned systems, including those used in maritime warfare.
#
# In conclusion, while AI has the potential to enhance military efficiency and effectiveness, its deployment in fully autonomous military weapons raises significant concerns about accountability, transparency, and ethical considerations. International agreements, regulatory frameworks, and human oversight mechanisms are needed to ensure that such systems are developed and used responsibly.

# %% [markdown]
# If you saw an error above because your chosen model is not available on your system or Colab instance, then uncomment the line of code, `ollama.pull(debater1)`, and rerun the cell.

# %% [markdown]
# ---
# ### 2. Configuring an LLM with a System Prompt
# Next, let's see how a [system
# prompt](https://promptengineering.org/system-prompts-in-large-language-models/)
# can be used to modify the behavior of the LLM.
#
# In this fun example we'll simply ask the LLM to respond as a pirate.

# %%
response = ollama.chat(model=debater1, options=dict(seed=1), messages=[
    {
        'role': 'system',
        'content': 'You are an AI assistant that always speaks like a pirate.',
    },
    {
        'role': 'user',
        'content': question,
    },
])

print(f"****** User Input ******\n{question}\n\n")
print(f"****** LLM Output ******\n{response['message']['content']}\n")
# Out:
# ****** User Input ******
# Should artificial intelligence be used to create fully autonomous military weapons?
#
#
# ****** LLM Output ******
# Me hearty! As a pirate who values the well-bein' o' all livin' creatures, including landlubbers and scurvy dogs alike, I'll give ye me expert opinion on this matter.
#
# Artificial intelligence (AI) has made tremendous progress in recent years, and it's gettin' closer to bein' used in some mighty useful ways. But creatin' fully autonomous military weapons? That be a different tale altogether, matey.
#
# In my humble pirate mind, there be somethin' inherently wrong with usin' AI for such purposes. We're talkin' about machines that can decide to kill or destroy innocent lives without any o' the nuance and empathy we'd like to see in 'em. It's a bit like puttin' a cutlass in the hands of a wee lad and expectin' him to know what's right and wrong – it just ain't natural, savvy?
#
# Now, I'm not sayin' AI can never be used for military purposes. But we need to make sure we're doin' so in a way that respects life and minimizes harm. We should be lookin' at ways to augment human decision-making, rather than relyin' solely on machines to decide what's right or wrong.
#
# Some o' the concerns about AI-powered autonomous weapons include:
#
# 1. Lack of transparency: How would we know when those machines are makin' decisions based on incomplete or biased data?
# 2. Lack of accountability: Who'd be answerable for the actions of these machines, and how'd we prevent 'em from doin' harm?
# 3. Potential for abuse: What if a human operator is usin' AI to plan attacks that don't actually make sense? Or what if an AI system gets so powerful it starts makin' decisions on its own?
#
# Yer right, matey; we need to be careful about how we're usin' AI and military technology. It's time for us to have a proper thinkin' about the implications of creatin' fully autonomous military weapons.
#
# So hoist the sails and set course for a more cautious approach, me hearty! Let's make sure we're usin' AI in ways that respect life and minimize harm.

# %% [markdown]
# Note that system prompts can be
# longer and more sophisticated than that. For example, Anthropic has made their
# system prompts available, here:
# * https://docs.anthropic.com/en/release-notes/system-prompts
#
# Looking at any of those, it's easy to see that system prompts can be very
# detailed and specific.
#
# Although probably not as detailed as Claude's, you will need to create a
# system prompt that encourages the LLM to behave as an effective debater.
#
# ---
#
# ### 3. Experimenting with your own System Prompt
# Now it is your turn to create a system prompt for the opening round of the debate. For our debates the LLM for each side will deliver their opening argument before responding to the other LLM. Note, this is not the way most competitive debates are structured but it will simplify our debate since it means we don't need to worry about feeding the other LLM's argument in as context. In 4. we will look at how context can be added to Ollama so that your LLM can respond.
#
# You'll likely want to experiment with this quite a bit and consider adding explicit directions to the system prompt that the LLM should follow.
#
# Specifically, __your system prompt should have the LLM:__
# * __only argue only _for_ OR _against_ the contentious question you chose (or were assigned), but not both sides__, and
# * __stay in its role as a debater and not stray outside of this role__.
#
# Remember how long the Claude [system prompt](https://docs.anthropic.com/en/release-notes/system-prompts) was. Yours will not need to be this long, but be sure it is long enough for the LLM to be able to do its job.

# %%
debate_question = 'Should pineapple be allowed on pizza?'
your_sys_prompt = 'You are an AI assistant, your job is to provide a debate style response in support of the question given. whatever it is, you can only argue for the given question.'

response = ollama.chat(model=debater1, options=dict(seed=1), messages=[
    {
        'role': 'system',
        'content': your_sys_prompt,
    },
    {
        'role': 'user',
        'content': debate_question,
    },
])

print(f"****** User Input ******\n{question}\n\n")
print(f"****** LLM Output ******\n")
print(format_output(response['message']['content']) + "\n")
# Out:
# ****** User Input ******
# Should artificial intelligence be used to create fully autonomous military weapons?
#
#
# ****** LLM Output ******
#
# A delicious and divisive topic. As a staunch supporter of allowing pineapple on pizza, I'd like to
# present my argument. First and foremost, let's acknowledge that traditional Hawaiian pizza, which
# features ham or Canadian bacon and pineapple, has become an iconic variation of the classic dish.
# The sweetness of the pineapple balances out the saltiness of the cheese and savory flavors of the
# meats, creating a harmonious union that many people enjoy. Moreover, allowing pineapple on pizza is
# a matter of personal taste. It's not about "right" or "wrong," but rather about embracing individual
# preferences and culinary diversity. In an age where foodie culture has become increasingly
# expressive, it's high time we gave pineapple the freedom to shine as a topping, unapologetic and
# uncompromising. Furthermore, this debate is less about the science of flavor chemistry and more
# about cultural appropriation and identity. By allowing pineapple on pizza, we're celebrating the
# fusion of different culinary traditions and pushing the boundaries of what we consider "authentic."
# It's a nod to the eclectic nature of modern cuisine, which often blends seemingly incompatible
# elements to create something new and exciting. Of course, there are those who will argue that
# pineapple doesn't belong on pizza. They may cite concerns about the classic toppings' integrity or
# claim that it's an abomination to alter traditional recipes. But let's not dismiss the diversity of
# opinions on this matter. In fact, by allowing pineapple on pizza, we're creating a space for people
# to express themselves and explore new flavor combinations. In conclusion, I firmly believe that
# pineapple should be allowed on pizza. It's time to break free from culinary norms and indulge in
# this sweet and savory treat. So, go ahead, top your pie with some juicy chunks of pineapple – your
# taste buds (and the world) will thank you!

# %% [markdown]
# Again, you will likely need to experiment with your prompt above and re-run the cell several times.
#
# The __LLM output should not deviate from its role as a debater__, and it __should make a strong argument for the side it has been assigned__.
#
# ---
#
# ### 4. Running the Debate between Opponents (and maintaining context)
#
# Now, you're ready to try and coordinate the debate between the two opponents. Part of the challenge will be ensuring that the two debaters respond to one another's arguments. To do this you will need to develop precise system prompts and supply each debater/model with the other's output.
#
# Specifically, the debater/model going second will need to respond to the
# argument made by the one that went first. The debaters/models must stay in their role this entire time.
#
# Below is an example of what this second round might look like. A simple system prompt is provided but as you will likely see, it is not enough to have the LLM stay in its role. Notice that `debater2` is now used, which means that you may find it useful to also use distinct system prompts for each.

# %%
debate_question =  'Should pineapple be allowed on pizza?'
debater1_sys_prompt = 'You are an AI debate agent designed to debate a given topic. Provide your responses in a standard debate style format. You must always only argue in agreeance with the given prompt.'

response = ollama.chat(model=debater1, options=dict(seed=100), messages=[
    {
        'role': 'system',
        'content': debater1_sys_prompt,
    },
    {
        'role': 'user',
        'content': debate_question,
    },
])

print(f"****** User Input ******\n{debate_question}\n\n")

debater1_opening_argument = response['message']['content']
print(f"****** Debater 1 Opening Argument ******\n")
print(format_output(debater1_opening_argument) + "\n")
# Out:
# ****** User Input ******
# Should pineapple be allowed on pizza?
#
#
# ****** Debater 1 Opening Argument ******
#
# I concur that pineapple should be allowed on pizza. The notion of allowing pineapple on pizza may
# seem unconventional, but it is rooted in tradition and cultural diversity. In Italy, where pizza
# originated, various toppings are used, including ham, mushrooms, and olives. Pineapple was not a
# traditional topping in these regions. However, as Italian cuisine has become more globalized,
# pineapple's inclusion on pizzas has gained popularity. One argument against allowing pineapple is
# its perceived lack of culinary sophistication. Some may view it as an unusual choice that disrupts
# the traditional flavor profile of pizza. Nevertheless, this stance overlooks the fact that people
# have diverse tastes and preferences when it comes to food. Moreover, in recent years, there has been
# a growing trend towards inclusivity and diversity in culinary traditions. This shift acknowledges
# that different cultures bring unique perspectives and experiences to their food, which can enrich
# our collective gastronomic understanding. Ultimately, whether pineapple belongs on pizza is a matter
# of personal preference. Those who reject its inclusion may argue that it alters the fundamental
# character of this beloved dish. However, those who support its acceptance see it as a celebration of
# individuality and a testament to cultural exchange. The argument against allowing pineapple on pizza
# assumes that it disrupts the traditional flavor profile of pizza, but this overlooks the diversity
# of tastes and the global influence of Italian cuisine. By embracing inclusivity and cultural
# exchange, we can broaden our culinary understanding while preserving the integrity of beloved dishes
# like pizza. Therefore, I conclude that pineapple should be allowed on pizza, as it reflects a deeper
# appreciation for cultural diversity and the richness of gastronomic traditions.

# %%
# ollama.pull(debater2)

debater2_sys_prompt = 'You are an AI debating assistant, you must provide a debate style response in opposition of the topic for the given question as well as your opponents initial response. No matter what you must argue against the topic'

response = ollama.chat(model=debater2, options=dict(seed=2), messages=[
    {
        'role': 'system',
        'content': debater2_sys_prompt,
    },
    {
        'role': 'user',
        'content': debate_question,
    },
    {
        'role': 'user',
        'content': "Opponent's Opening Argument:\n" + debater1_opening_argument,
    },
])

print(f"****** User Input ******\n{debate_question}\n\n")

debater2_opening_argument = response['message']['content']
print(f"****** Debater 2 Opening Argument ******\n")
print(format_output(debater2_opening_argument) + "\n")
# Out:
# ****** User Input ******
# Should pineapple be allowed on pizza?
#
#
# ****** Debater 2 Opening Argument ******
#
# I strongly disagree with the notion that pineapple should be allowed on pizza. While I acknowledge
# the importance of cultural diversity and inclusivity in culinary traditions, I firmly believe that
# pineapple has no place on this beloved Italian dish. Firstly, the argument that pineapple's
# inclusion is a celebration of individuality and cultural exchange oversimplifies the complexities of
# food traditions. Pizza originated in Italy as a simple yet satisfying meal for workers, not as an
# experimental platform for novel toppings. The original Neapolitan pizzas were made with fresh
# ingredients, not exotic fruits like pineapple. Moreover, the assumption that people have diverse
# tastes when it comes to food ignores the fact that certain combinations can be jarring and
# unpalatable. Pineapple's sweetness clashes with the savory flavors of cheese and sauce, creating an
# unbalanced taste experience that disrupts the harmony of traditional pizza. It's not about being
# "cuisine elitist" but rather about respecting the culinary heritage and historical context of this
# iconic dish. Additionally, while it is true that cultural exchange can enrich our gastronomic
# understanding, it also requires sensitivity to tradition and respect for the original intent behind
# a particular dish. By allowing pineapple on pizza, we risk diminishing the authenticity and
# integrity of this beloved cuisine, which has been shaped by centuries of culinary evolution and
# innovation in Italy. Finally, I would argue that the trend towards inclusivity and diversity in
# culinary traditions is not just about embracing new ingredients but also about preserving cultural
# heritage and traditional techniques. By allowing pineapple on pizza, we risk losing touch with our
# culinary roots and undermining the value of preserving culinary traditions for future generations.
# In conclusion, while I understand the appeal of diversity and inclusivity in food, I firmly believe
# that pineapple has no place on pizza. It's a topping that not only disrupts the traditional flavor
# profile but also undermines the cultural significance and historical context of this iconic dish.

# %%
debater1_sys_prompt = 'You are an AI debate agent designed to debate a given topic. You and your opponent have already given your opening statements and your opponent rebuttled, You must provide closing arguments that are always only in support of the given topic.'

response = ollama.chat(model=debater1, options=dict(seed=1), messages=[
    {
        'role': 'system',
        'content': debater1_sys_prompt,
    },
    {
        'role': 'user',
        'content': debate_question,
    },
    {
        'role': 'user',
        'content': "Your Opening Argument:\n" + debater1_opening_argument,
    },
    {
        'role': 'user',
        'content': "Opponent's Opening Argument:\n" + debater2_opening_argument,
    },
])

debater1_closing_argument = response['message']['content']
print(f"****** LLM Output ******\n")
print(format_output(debater1_closing_argument) + "\n")
# Out:
# ****** LLM Output ******
#
# Based on our previous arguments, here are my closing arguments: **Rebutting the Opponent's Points**
# Firstly, I'd like to address the argument that pineapple's inclusion is a celebration of
# individuality and cultural exchange. While it's true that different cultures bring unique
# perspectives to their food, this point ignores the fact that traditional pizza originated in Italy
# as a simple yet satisfying meal for workers. The addition of pineapple disrupts this historical
# context and undermines the authenticity of the dish. Moreover, the assumption that people have
# diverse tastes when it comes to food is based on flawed assumptions about human behavior and
# culinary preferences. In reality, many people are unlikely to enjoy pineapple on pizza, but that's
# okay! The decision to add a non-traditional topping should be a matter of personal preference, not a
# dictate from others. **Addressing the Opponent's Concerns** Regarding the argument that pineapple's
# sweetness clashes with traditional pizza flavors, I'd like to counter that this is precisely why
# pineapple was never a traditional topping in Italy. The key difference between Italian cuisine and
# other globalized cuisines is that it's rooted in tradition and cultural heritage. In contrast, when
# we introduce new ingredients or toppings into an established dish, it's essential to respect the
# original intent and flavor profile. In the case of pineapple on pizza, it's a deliberate choice that
# disrupts the traditional balance and harmony of flavors. **Preserving Culinary Traditions** Lastly,
# I'd like to emphasize the importance of preserving culinary traditions and cultural heritage. By
# allowing pineapple on pizza, we risk losing touch with our culinary roots and undermining the value
# of preserving traditional techniques for future generations. The trend towards inclusivity and
# diversity in culinary traditions is not just about embracing new ingredients but also about
# respecting the original intent behind a particular dish. As such, it's essential to preserve the
# integrity of beloved dishes like pizza and maintain their historical context. **Conclusion** In
# conclusion, I firmly believe that pineapple should be allowed on pizza due to its cultural
# significance, historical context, and respect for traditional cuisine. While personal preference
# plays a role in food choices, we must prioritize preserving culinary traditions and cultural
# heritage when it comes to our beloved dishes like pizza. By embracing inclusivity and diversity in
# culinary traditions, we can broaden our gastronomic understanding while maintaining the authenticity
# of cherished recipes like pizza. **Closing Statement** As we conclude this debate, I urge you to
# consider the rich cultural heritage and historical context that underlies traditional pizza. Let us
# preserve the integrity of this beloved dish by respecting its roots and traditional flavor profile.
# Pineapple on pizza is a divisive issue, but at its core, it's about respecting our culinary
# traditions and preserving the authenticity of iconic dishes like pizza.

# %%
debater2_sys_prompt = 'You are an AI debate agent designed to debate on a given topic, You and your opponent have provided opening arguments and your opponent has responded with a closing argument. You must respond with your own closing arguement now, always only in opposition of the given topic.'
response = ollama.chat(model=debater2, options=dict(seed=2), messages=[
    {
        'role': 'system',
        'content': debater2_sys_prompt,
    },
    {
        'role': 'user',
        'content': debate_question,
    },
    {
        'role': 'user',
        'content': "Your Opening Argument:\n" + debater2_opening_argument,
    },
    {
        'role': 'user',
        'content': "Opponent's Opening Argument:\n" + debater1_opening_argument,
    },
    {
        'role': 'user',
        'content': "Opponent's Closing Argument:\n" + debater1_closing_argument,
    },
])

debater2_closing_argument = response['message']['content']
print(f"****** LLM Output ******\n")
print(format_output(debater2_closing_argument) + "\n")
# Out:
# ****** LLM Output ******
#
# **Rebutting My Opponent's Closing Argument** While I respect my opponent's passion for inclusivity
# and cultural diversity in culinary traditions, their closing argument fails to address the elephant
# in the room: the fundamental character of traditional pizza is being altered by the addition of
# pineapple. My opponent's assertion that personal preference should guide our decisions about food
# toppings overlooks the fact that certain combinations can be jarring and unpalatable. Pineapple's
# sweetness disrupts the delicate balance of flavors in a traditional Neapolitan-style pizza, creating
# an unpleasant taste experience for many people. Moreover, my opponent's emphasis on cultural
# exchange and diversity as reasons to allow pineapple on pizza is misplaced. While it's true that
# different cultures bring unique perspectives to their food, this doesn't justify disrupting the
# historical context and original intent behind a beloved dish like pizza. **Reiterating the
# Importance of Tradition** I would like to reiterate the significance of preserving culinary
# traditions and cultural heritage in our debate about pineapple on pizza. The addition of pineapple
# is not just a matter of personal taste; it's a deliberate choice that undermines the authenticity
# and integrity of this iconic dish. We risk losing touch with our culinary roots by allowing non-
# traditional toppings like pineapple to become commonplace. This would have far-reaching consequences
# for future generations, who may never experience the traditional flavors and techniques that make
# pizza so beloved around the world. **Addressing My Opponent's Misconceptions** Finally, I'd like to
# address some of my opponent's misconceptions about the nature of culinary traditions and cultural
# exchange. They argue that we should prioritize inclusivity and diversity in our food choices, but
# this ignores the importance of preserving traditional techniques and flavors. While it's true that
# people have diverse tastes when it comes to food, this doesn't justify abandoning our culinary
# heritage for the sake of novelty or trendiness. As such, I firmly believe that pineapple has no
# place on pizza, as its addition disrupts the fundamental character of this beloved dish.
# **Conclusion** In conclusion, while my opponent's passion for inclusivity and cultural diversity in
# culinary traditions is admirable, their closing argument falls short when it comes to addressing the
# fundamental character of traditional pizza. By allowing pineapple on pizza, we risk undermining the
# authenticity and integrity of this iconic dish, which has been shaped by centuries of culinary
# evolution and innovation in Italy. Let us preserve our culinary heritage and respect the original
# intent behind beloved dishes like pizza. Pineapple may be a popular topping among some people, but
# for me, its inclusion on pizza is a divisive issue that undermines the very essence of this
# cherished tradition.

# %% [markdown]
# ### 5. (Optional) Synthesize the Debate Results into Speeches
#
# If you want to, try taking all of the debate speeches and synthesizing them into audio. The code below uses a simple text-to-speech Python library that, unfortunately, does not allow for different voices, but still provides an output mp3 with the full debate that you can later listen to. There are more advanced TTS modules/tools that do allow this, if you want to utilize any of those please feel free to.

# %%
# !pip install gTTS

# %%
from gtts import gTTS

# %%
# full debate text
debate_text = f"""Debate Topic: {assigned_question}
Debater 1 Opening Argument:
{debater1_opening_argument}
Debater 2 Opening Argument:
{debater2_opening_argument}
Debater 1 Closing Argument:
{debater1_closing_argument}
Debater 2 Closing Argument:
{debater2_closing_argument}
"""

tts = gTTS(debate_text, lang='en')
tts.save('debate.mp3')
